# %%
import pandas as pd
import numpy as np
import shap
from sklearn import set_config
import matplotlib.pyplot as plt
import seaborn as sns
set_config(transform_output="pandas")

# %%
# load the data

df = pd.read_csv('/content/Churn_Modelling.csv')

df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# shape of the data

df.shape
# Out:
# (10000, 14)

# %%
# check for missing values

df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.isna().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
# find the rows having missing values

(
    df.loc[
        (df.isna().any(axis=1)), :
    ]
)
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
# drop the missing rows

df.dropna(inplace=True)

# %%
# missing values

df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
# check for duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# duplicate rows

(
    df
    .loc[
        df.duplicated(keep=False), :
    ]

)
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
# drop the duplicate rows

df.drop_duplicates(inplace=True)

# %%
# duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## EDA

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
# drop the first three columns

columns_to_drop = df.columns[0:3]

columns_to_drop
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname'], dtype='object')

# %%
# drop the columns

df.drop(columns=columns_to_drop, inplace=True)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
# lowercase the column names

df.rename(columns=str.lower, inplace=True)

# %%
df.columns
# Out:
# Index(['creditscore', 'geography', 'gender', 'age', 'tenure', 'balance',
#        'numofproducts', 'hascrcard', 'isactivemember', 'estimatedsalary',
#        'exited'],
#       dtype='object')

# %%
# make our X and y

X = df.drop(columns=["exited"])

y = df["exited"]

# %%
X
# Out:
#       creditscore geography  gender  age  tenure    balance  numofproducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       hascrcard  isactivemember  estimatedsalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: exited, Length: 10000, dtype: int64

# %%
# datatype

df.dtypes
# Out:
# creditscore          int64
# geography           object
# gender              object
# age                  int64
# tenure               int64
# balance            float64
# numofproducts        int64
# hascrcard            int64
# isactivemember       int64
# estimatedsalary    float64
# exited               int64
# dtype: object

# %%
# list of columns

numerical_cols = ["creditscore", "age", "balance", "estimatedsalary"]

categorical_cols = ["gender", "geography"]

# %%
numerical_cols
# Out:
# ['creditscore', 'age', 'balance', 'estimatedsalary']

# %%
remainder_cols = [column_name for column_name in X.columns if column_name not in numerical_cols + categorical_cols]

remainder_cols
# Out:
# ['tenure', 'numofproducts', 'hascrcard', 'isactivemember']

# %%
df[numerical_cols]
# Out:
#       creditscore  age    balance  estimatedsalary
# 0             619   42       0.00        101348.88
# 1             608   41   83807.86        112542.58
# 2             502   42  159660.80        113931.57
# 3             699   39       0.00         93826.63
# 4             850   43  125510.82         79084.10
# ...           ...  ...        ...              ...
# 9995          771   39       0.00         96270.64
# 9996          516   35   57369.61        101699.77
# 9997          709   36       0.00         42085.58
# 9998          772   42   75075.31         92888.52
# 9999          792   28  130142.79         38190.78
#
# [10000 rows x 4 columns]

# %%
df[categorical_cols]
# Out:
#       gender geography
# 0     Female    France
# 1     Female     Spain
# 2     Female    France
# 3     Female    France
# 4     Female     Spain
# ...      ...       ...
# 9995    Male    France
# 9996    Male    France
# 9997  Female    France
# 9998    Male   Germany
# 9999  Female    France
#
# [10000 rows x 2 columns]

# %%
df[remainder_cols]
# Out:
#       tenure  numofproducts  hascrcard  isactivemember
# 0          2              1          1               1
# 1          1              1          0               1
# 2          8              3          1               0
# 3          1              2          0               0
# 4          2              1          1               1
# ...      ...            ...        ...             ...
# 9995       5              2          1               0
# 9996      10              1          1               1
# 9997       7              1          0               1
# 9998       3              2          1               0
# 9999       4              1          1               0
#
# [10000 rows x 4 columns]

# %%
from matplotlib.gridspec import GridSpec

# %%
def plots_for_numerical_columns(column_name, bins, kde=True):
    # set the figure size
    fig = plt.figure(figsize=(8,6))
    # gridspec
    grid = GridSpec(nrows=2, ncols=2, height_ratios=[0.6,0.4])

    # define the axes
    ax1 = plt.subplot(grid[0,:])
    ax2 = plt.subplot(grid[1,:])

    # plot the histogram
    sns.histplot(data=X, x=column_name, bins=bins, kde=kde, ax=ax1)

    # plot the boxplot
    sns.boxplot(data=df,x=column_name,ax=ax2)

    plt.show()

# %%
# bins for the histogram

col_bins = {
    column_name:bin_val for column_name, bin_val in zip(numerical_cols, [50,15,"auto","auto"])
}

col_bins
# Out:
# {'creditscore': 50, 'age': 15, 'balance': 'auto', 'estimatedsalary': 'auto'}

# %%
for num_col in numerical_cols:
    print(f"{num_col.title()}", end="\n\n")
    plots_for_numerical_columns(column_name=num_col, bins=col_bins[num_col])
    print("\n\n")
# Out:
# Creditscore
# Age
# Balance
# Estimatedsalary

# %%
# people with 0 bal

(
    X.loc[
        (X["balance"].eq(0)), :
    ]
)
# Out:
#       creditscore geography  gender  age  tenure  balance  numofproducts  \
# 0             619    France  Female   42       2      0.0              1
# 3             699    France  Female   39       1      0.0              2
# 6             822    France    Male   50       7      0.0              2
# 11            497     Spain    Male   24       3      0.0              2
# 12            476    France  Female   34      10      0.0              2
# ...           ...       ...     ...  ...     ...      ...            ...
# 9989          841     Spain    Male   28       4      0.0              2
# 9992          726     Spain    Male   36       2      0.0              1
# 9994          800    France  Female   29       2      0.0              2
# 9995          771    France    Male   39       5      0.0              2
# 9997          709    France  Female   36       7      0.0              1
#
#       hascrcard  isactivemember  estimatedsalary
# 0             1               1        101348.88
# 3             0               0         93826.63
# 6             1               1         10062.80
# 11            1               0         76390.01
# 12            1               0         26260.98
# ...         ...             ...              ...
# 9989          1               1        179436.60
# 9992          1               0        195192.40
# 9994          0               0        167773.55
# 9995          1               0         96270.64
# 9997          0               1         42085.58
#
# [3617 rows x 10 columns]

# %%
X["balance"].eq(0)
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 9995     True
# 9996    False
# 9997     True
# 9998    False
# 9999    False
# Name: balance, Length: 10000, dtype: bool

# %%
# new col for 0 bal customers

X["iszerobal"] = X["balance"].eq(0).astype(int)

# %%
X
# Out:
#       creditscore geography  gender  age  tenure    balance  numofproducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       hascrcard  isactivemember  estimatedsalary  iszerobal
# 0             1               1        101348.88          1
# 1             0               1        112542.58          0
# 2             1               0        113931.57          0
# 3             0               0         93826.63          1
# 4             1               1         79084.10          0
# ...         ...             ...              ...        ...
# 9995          1               0         96270.64          1
# 9996          1               1        101699.77          0
# 9997          0               1         42085.58          1
# 9998          1               0         92888.52          0
# 9999          1               0         38190.78          0
#
# [10000 rows x 11 columns]

# %%
def plots_for_categorical_cols(column_name):
    display(X[column_name].value_counts(normalize=True))
    print(f"There are {X[column_name].nunique()} unique values in the column {column_name} which are {X[column_name].unique()}")
    # plot the count plot
    sns.countplot(data=X,x=column_name)
    plt.show()

# %%
for cat_col in categorical_cols:
    print(f"{cat_col.title()}")
    plots_for_categorical_cols(cat_col)
    print("\n\n")
# Out:
# Gender
# gender
# Male      0.5457
# Female    0.4543
# Name: proportion, dtype: float64
# There are 2 unique values in the column gender which are ['Female' 'Male']
# Geography
# geography
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: proportion, dtype: float64
# There are 3 unique values in the column geography which are ['France' 'Spain' 'Germany']

# %%
X
# Out:
#       creditscore geography  gender  age  tenure    balance  numofproducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       hascrcard  isactivemember  estimatedsalary  iszerobal
# 0             1               1        101348.88          1
# 1             0               1        112542.58          0
# 2             1               0        113931.57          0
# 3             0               0         93826.63          1
# 4             1               1         79084.10          0
# ...         ...             ...              ...        ...
# 9995          1               0         96270.64          1
# 9996          1               1        101699.77          0
# 9997          0               1         42085.58          1
# 9998          1               0         92888.52          0
# 9999          1               0         38190.78          0
#
# [10000 rows x 11 columns]

# %%
# distribution of target

y.value_counts(normalize=True)
# Out:
# exited
# 0    0.7963
# 1    0.2037
# Name: proportion, dtype: float64

# %% [markdown]
# ## FE and Model training

# %%
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %%
# split the data

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=30,stratify=y)

# %%
print(f"The shape of training data is {X_train.shape}")
print(f"The shape of test data is {X_test.shape}")
# Out:
# The shape of training data is (8000, 11)
# The shape of test data is (2000, 11)

# %%
# column transformer

scaler = MinMaxScaler()

encoder = OneHotEncoder(handle_unknown="ignore",sparse_output=False)

preprocessor = ColumnTransformer(transformers=[
    ("scaler",scaler,numerical_cols),
    ("encoder",encoder,categorical_cols)
], remainder="passthrough",verbose_feature_names_out=False)

# %%
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('scaler', MinMaxScaler(),
#                                  ['creditscore', 'age', 'balance',
#                                   'estimatedsalary']),
#                                 ('encoder',
#                                  OneHotEncoder(handle_unknown='ignore',
#                                                sparse_output=False),
#                                  ['gender', 'geography'])],
#                   verbose_feature_names_out=False)

# %%
# apply the transformation

X_train = preprocessor.fit_transform(X_train)

X_test = preprocessor.transform(X_test)

# %%
X_train
# Out:
#       creditscore       age   balance  estimatedsalary  gender_Female  \
# 3491        0.440  0.229730  0.341448         0.527619            0.0
# 3479        0.236  0.378378  0.364466         0.054738            0.0
# 5098        0.400  0.148649  0.579096         0.737433            0.0
# 5370        0.664  0.310811  0.000000         0.670797            0.0
# 7763        0.528  0.243243  0.175589         0.366623            1.0
# ...           ...       ...       ...              ...            ...
# 5030        0.424  0.202703  0.369310         0.006714            0.0
# 9619        0.668  0.229730  0.398440         0.884437            0.0
# 5972        0.396  0.418919  0.432199         0.635117            0.0
# 3160        0.482  0.135135  0.000000         0.243000            0.0
# 4052        0.532  0.310811  0.451260         0.570361            0.0
#
#       gender_Male  geography_France  geography_Germany  geography_Spain  \
# 3491          1.0               0.0                1.0              0.0
# 3479          1.0               1.0                0.0              0.0
# 5098          1.0               0.0                1.0              0.0
# 5370          1.0               1.0                0.0              0.0
# 7763          0.0               0.0                0.0              1.0
# ...           ...               ...                ...              ...
# 5030          1.0               0.0                1.0              0.0
# 9619          1.0               0.0                1.0              0.0
# 5972          1.0               0.0                1.0              0.0
# 3160          1.0               1.0                0.0              0.0
# 4052          1.0               0.0                1.0              0.0
#
#       tenure  numofproducts  hascrcard  isactivemember  iszerobal
# 3491       6              1          1               0          0
# 3479       7              1          1               0          0
# 5098       9              2          1               0          0
# 5370       6              2          0               1          1
# 7763       1              1          1               1          0
# ...      ...            ...        ...             ...        ...
# 5030       8              2          1               0          0
# 9619       3              1          1               1          0
# 5972       9              1          0               0          0
# 3160       5              2          1               1          1
# 4052      10              2          1               1          0
#
# [8000 rows x 14 columns]

# %%
X_test
# Out:
#       creditscore       age   balance  estimatedsalary  gender_Female  \
# 2576        0.590  0.243243  0.238718         0.219961            0.0
# 5875        0.324  0.202703  0.484999         0.418392            1.0
# 7668        0.352  0.581081  0.533465         0.225868            0.0
# 2560        0.600  0.162162  0.000000         0.339960            1.0
# 1775        0.398  0.270270  0.427598         0.787231            1.0
# ...           ...       ...       ...              ...            ...
# 3022        0.596  0.121622  0.000000         0.815322            1.0
# 8256        0.642  0.540541  0.712297         0.108794            0.0
# 5436        0.962  0.216216  0.000000         0.829226            1.0
# 3063        0.518  0.189189  0.286460         0.759639            0.0
# 5580        0.532  0.162162  0.000000         0.995535            0.0
#
#       gender_Male  geography_France  geography_Germany  geography_Spain  \
# 2576          1.0               0.0                0.0              1.0
# 5875          0.0               1.0                0.0              0.0
# 7668          1.0               0.0                1.0              0.0
# 2560          0.0               0.0                0.0              1.0
# 1775          0.0               1.0                0.0              0.0
# ...           ...               ...                ...              ...
# 3022          0.0               0.0                0.0              1.0
# 8256          1.0               0.0                0.0              1.0
# 5436          0.0               1.0                0.0              0.0
# 3063          1.0               1.0                0.0              0.0
# 5580          1.0               0.0                0.0              1.0
#
#       tenure  numofproducts  hascrcard  isactivemember  iszerobal
# 2576       4              2          1               0          0
# 5875       6              2          1               1          0
# 7668       6              2          1               1          0
# 2560       6              1          0               0          1
# 1775       8              1          0               0          0
# ...      ...            ...        ...             ...        ...
# 3022       7              2          1               1          1
# 8256       1              1          1               1          0
# 5436       2              2          0               0          1
# 3063       7              1          1               1          0
# 5580       2              2          1               0          1
#
# [2000 rows x 14 columns]

# %% [markdown]
# ### Model Building

# %%
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.ensemble import VotingClassifier

# %%
# define models

rf = RandomForestClassifier(class_weight="balanced", random_state=42)

xgb = XGBClassifier(class_weight="balanced", random_state=42)

lgbm = LGBMClassifier(class_weight="balanced", random_state=42)

# %%
# build a voting classifier

model = VotingClassifier(estimators=[
    ("rf",rf),
    ("xgb",xgb),
    ("lgbm",lgbm)
], voting="soft",n_jobs=-1)

model
# Out:
# VotingClassifier(estimators=[('rf',
#                               RandomForestClassifier(class_weight='balanced',
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             class_weight='balanced',
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=True,
#                                             eval_metric=None,
#                                             feature_types=...
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=None, n_jobs=None, ...)),
#                              ('lgbm',
#                               LGBMClassifier(class_weight='balanced',
#                                              random_state=42))],
#                  n_jobs=-1, voting='soft')

# %%
# fit the model on the dataset

model.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('rf',
#                               RandomForestClassifier(class_weight='balanced',
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             class_weight='balanced',
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=True,
#                                             eval_metric=None,
#                                             feature_types=...
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=None, n_jobs=None, ...)),
#                              ('lgbm',
#                               LGBMClassifier(class_weight='balanced',
#                                              random_state=42))],
#                  n_jobs=-1, voting='soft')

# %%
# get the predictions

y_pred = model.predict(X_test)

# %%
model.predict_proba(X_test.iloc[0:5,:])
# Out:
# array([[0.80386407, 0.19613592],
#        [0.92765243, 0.07234756],
#        [0.79748834, 0.20251166],
#        [0.70572878, 0.29427122],
#        [0.65115831, 0.34884168]])

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      1593
#            1       0.70      0.56      0.62       407
#
#     accuracy                           0.86      2000
#    macro avg       0.80      0.75      0.77      2000
# weighted avg       0.85      0.86      0.86      2000

# %% [markdown]
# #### HP Tuning

# %%
import optuna
from sklearn.model_selection import cross_val_score, StratifiedKFold

# %%
model
# Out:
# VotingClassifier(estimators=[('rf',
#                               RandomForestClassifier(class_weight='balanced',
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             class_weight='balanced',
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=True,
#                                             eval_metric=None,
#                                             feature_types=...
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=None, n_jobs=None, ...)),
#                              ('lgbm',
#                               LGBMClassifier(class_weight='balanced',
#                                              random_state=42))],
#                  n_jobs=-1, voting='soft')

# %%
model.estimators
# Out:
# [('rf', RandomForestClassifier(class_weight='balanced', random_state=42)),
#  ('xgb',
#   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 class_weight='balanced', colsample_bylevel=None,
#                 colsample_bynode=None, colsample_bytree=None, device=None,
#                 early_stopping_rounds=None, enable_categorical=True,
#                 eval_metric=None, feature_types=None, feature_weights=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None, ...)),
#  ('lgbm', LGBMClassifier(class_weight='balanced', random_state=42))]

# %%
def objective(trial: optuna.Trial):

    params_dict = {
        "rf__n_estimators": trial.suggest_int("rf__n_estimators", 50, 200),
        "rf__max_depth": trial.suggest_int("rf__max_depth", 5, 12),
        "rf__max_samples": trial.suggest_float("rf__max_samples", 0.5, 1.0),
        "xgb__learning_rate": trial.suggest_float("xgb__learning_rate", 0.01, 0.5),
        "xgb__max_depth": trial.suggest_int("xgb__max_depth", 5, 15),
        "xgb__n_estimators": trial.suggest_int("xgb__n_estimators", 30, 200),
        "xgb__subsample": trial.suggest_float("xgb__subsample", 0.5,1.0),
        "xgb__colsample_bynode": trial.suggest_float("xgb__colsample_bynode", 0.7, 1.0),
        "xgb__reg_lambda": trial.suggest_float("xgb__reg_lambda",0.1,10.0),
        "lgbm__max_depth": trial.suggest_int("lgbm__max_depth", 5, 15),
        "lgbm__n_estimators": trial.suggest_int("lgbm__n_estimators", 30, 200),
        "lgbm__learning_rate": trial.suggest_float("lgbm__learning_rate", 0.01, 0.5),
        "lgbm__subsample": trial.suggest_float("lgbm__subsample", 0.5,1.0),
        "lgbm__reg_lambda": trial.suggest_float("lgbm__reg_lambda",0.1,10.0)
    }

    # define models
    rf = RandomForestClassifier(class_weight="balanced", random_state=42)
    xgb = XGBClassifier(class_weight="balanced", random_state=42)
    lgbm = LGBMClassifier(class_weight="balanced", random_state=42)

    # build a voting classifier
    model = VotingClassifier(estimators=[
        ("rf",rf),
        ("xgb",xgb),
        ("lgbm",lgbm)
    ], voting="soft",n_jobs=-1)

    # pass parameters to model
    model.set_params(**params_dict)

    # cross validation
    scores = cross_val_score(estimator=model,
                             X=X_train, y=y_train,
                             scoring="f1",
                             cv=StratifiedKFold(n_splits=5,random_state=10,shuffle=True),
                             n_jobs=-1)

    # mean f1
    mean_f1 = np.mean(scores)

    return mean_f1

# %%
# define my study

study = optuna.create_study(direction="maximize")

study.optimize(func=objective,n_trials=20,n_jobs=-1,show_progress_bar=True)
# Out:
# [I 2026-08-02 08:12:58,071] A new study created in memory with name: no-name-84ad30d5-cfb8-4278-8584-673e7177a379
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-08-02 08:13:12,170] Trial 0 finished with value: 0.5904764373142333 and parameters: {'rf__n_estimators': 94, 'rf__max_depth': 12, 'rf__max_samples': 0.8767983375925114, 'xgb__learning_rate': 0.030355682155362225, 'xgb__max_depth': 6, 'xgb__n_estimators': 51, 'xgb__subsample': 0.8971841767221314, 'xgb__colsample_bynode': 0.8398877915012425, 'xgb__reg_lambda': 4.658808521040059, 'lgbm__max_depth': 12, 'lgbm__n_estimators': 105, 'lgbm__learning_rate': 0.41700962647373685, 'lgbm__subsample': 0.7737761253440609, 'lgbm__reg_lambda': 1.94780240721862}. Best is trial 0 with value: 0.5904764373142333.
# [I 2026-08-02 08:13:19,136] Trial 1 finished with value: 0.6088958980981218 and parameters: {'rf__n_estimators': 186, 'rf__max_depth': 8, 'rf__max_samples': 0.9539636410858563, 'xgb__learning_rate': 0.15171096993741173, 'xgb__max_depth': 11, 'xgb__n_estimators': 48, 'xgb__subsample': 0.6872128509566866, 'xgb__colsample_bynode': 0.7312024595820671, 'xgb__reg_lambda': 5.864528763642508, 'lgbm__max_depth': 13, 'lgbm__n_estimators': 184, 'lgbm__learning_rate': 0.21711387456352715, 'lgbm__subsample': 0.8106580348224484, 'lgbm__reg_lambda': 2.9440071179363483}. Best is trial 1 with value: 0.6088958980981218.
# [I 2026-08-02 08:13:30,273] Trial 2 finished with value: 0.6096471012863823 and parameters: {'rf__n_estimators': 174, 'rf__max_depth': 9, 'rf__max_samples': 0.5686356142326354, 'xgb__learning_rate': 0.46486172728117475, 'xgb__max_depth': 8, 'xgb__n_estimators': 84, 'xgb__subsample': 0.9800357920249203, 'xgb__colsample_bynode': 0.8793080761410198, 'xgb__reg_lambda': 4.149329793525087, 'lgbm__max_depth': 8, 'lgbm__n_estimators': 114, 'lgbm__learning_rate': 0.05834370704797781, 'lgbm__subsample': 0.5649043475166635, 'lgbm__reg_lambda': 7.430778905574005}. Best is trial 2 with value: 0.6096471012863823.
# [I 2026-08-02 08:13:56,482] Trial 3 finished with value: 0.5957024871626141 and parameters: {'rf__n_estimators': 148, 'rf__max_depth': 10, 'rf__max_samples': 0.9302255096293821, 'xgb__learning_rate': 0.3297596693022316, 'xgb__max_depth': 7, 'xgb__n_estimators': 184, 'xgb__subsample': 0.7667352607675051, 'xgb__colsample_bynode': 0.9153967115132938, 'xgb__reg_lambda': 4.10448791539234, 'lgbm__max_depth': 7, 'lgbm__n_estimators': 109, 'lgbm__learning_rate': 0.3112009088752397, 'lgbm__subsample': 0.8403868473540297, 'lgbm__reg_lambda': 2.481511499305981}. Best is trial 2 with value: 0.6096471012863823.
# [I 2026-08-02 08:13:59,604] Trial 4 finished with value: 0.5891494601135184 and parameters: {'rf__n_estimators': 132, 'rf__max_depth': 12, 'rf__max_samples': 0.8701742534441872, 'xgb__learning_rate': 0.3482895489647907, 'xgb__max_depth': 13, 'xgb__n_estimators': 98, 'xgb__subsample': 0.6572146503024334, 'xgb__colsample_bynode': 0.7248251763696146, 'xgb__reg_lambda': 7.433748032589188, 'lgbm__max_depth': 15, 'lgbm__n_estimators': 196, 'lgbm__learning_rate': 0.3478770818627842, 'lgbm__subsample': 0.9659110922485847, 'lgbm__reg_lambda': 1.2257383886329394}. Best is trial 2 with value: 0.6096471012863823.
# [I 2026-08-02 08:14:21,888] Trial 5 finished with value: 0.5859790573825996 and parameters: {'rf__n_estimators': 175, 'rf__max_depth': 12, 'rf__max_samples': 0.6234974223539896, 'xgb__learning_rate': 0.2841550110771988, 'xgb__max_depth': 10, 'xgb__n_estimators': 141, 'xgb__subsample': 0.986497237909004, 'xgb__colsample_bynode': 0.7834135756950786, 'xgb__reg_lambda': 6.1955263423498295, 'lgbm__max_depth': 8, 'lgbm__n_estimators': 189, 'lgbm__learning_rate': 0.49445648828189, 'lgbm__subsample': 0.7485447963235361, 'lgbm__reg_lambda': 5.158293477176033}. Best is trial 2 with value: 0.6096471012863823.
# [I 2026-08-02 08:14:23,679] Trial 6 finished with value: 0.6179168246395897 and parameters: {'rf__n_estimators': 152, 'rf__max_depth': 7, 'rf__max_samples': 0.7387720588576155, 'xgb__learning_rate': 0.0804296309092502, 'xgb__max_depth': 13, 'xgb__n_estimators': 168, 'xgb__subsample': 0.9009578877949174, 'xgb__colsample_bynode': 0.8551286016188187, 'xgb__reg_lambda': 1.9650578730193191, 'lgbm__max_depth': 13, 'lgbm__n_estimators': 141, 'lgbm__learning_rate': 0.020153691555269485, 'lgbm__subsample': 0.731008129736211, 'lgbm__reg_lambda': 9.720194534317828}. Best is trial 6 with value: 0.6179168246395897.
# [I 2026-08-02 08:14:36,263] Trial 7 finished with value: 0.6131696945188295 and parameters: {'rf__n_estimators': 160, 'rf__max_depth': 5, 'rf__max_samples': 0.7824956091380944, 'xgb__learning_rate': 0.041996653904880166, 'xgb__max_depth': 14, 'xgb__n_estimators': 81, 'xgb__subsample': 0.8598486770573655, 'xgb__colsample_bynode': 0.9462607474502864, 'xgb__reg_lambda': 5.994577241630269, 'lgbm__max_depth': 15, 'lgbm__n_estimators': 65, 'lgbm__learning_rate': 0.1525568283276828, 'lgbm__subsample': 0.9856478617393029, 'lgbm__reg_lambda': 3.6393702682831766}. Best is trial 6 with value: 0.6179168246395897.
# [I 2026-08-02 08:14:37,387] Trial 8 finished with value: 0.600478376913237 and parameters: {'rf__n_estimators': 122, 'rf__max_depth': 10, 'rf__max_samples': 0.6357597994876523, 'xgb__learning_rate': 0.4086271613391329, 'xgb__max_depth': 9, 'xgb__n_estimators': 49, 'xgb__subsample': 0.7926827491126495, 'xgb__colsample_bynode': 0.9039618040708379, 'xgb__reg_lambda': 1.002147005425699, 'lgbm__max_depth': 15, 'lgbm__n_estimators': 43, 'lgbm__learning_rate': 0.35743451674394994, 'lgbm__subsample': 0.6276442881534949, 'lgbm__reg_lambda': 3.862825784635289}. Best is trial 6 with value: 0.6179168246395897.
# [I 2026-08-02 08:14:48,244] Trial 9 finished with value: 0.6131515784722597 and parameters: {'rf__n_estimators': 126, 'rf__max_depth': 10, 'rf__max_samples': 0.9490258419907407, 'xgb__learning_rate': 0.21081115098058287, 'xgb__max_depth': 8, 'xgb__n_estimators': 39, 'xgb__subsample': 0.8686948985822144, 'xgb__colsample_bynode': 0.879944240664944, 'xgb__reg_lambda': 1.854460117159647, 'lgbm__max_depth': 10, 'lgbm__n_estimators': 161, 'lgbm__learning_rate': 0.09562333673089005, 'lgbm__subsample': 0.6759957512910358, 'lgbm__reg_lambda': 3.9464550013262336}. Best is trial 6 with value: 0.6179168246395897.
# [I 2026-08-02 08:14:49,386] Trial 10 finished with value: 0.6102008529620354 and parameters: {'rf__n_estimators': 147, 'rf__max_depth': 5, 'rf__max_samples': 0.7668839036462709, 'xgb__learning_rate': 0.1711945408735196, 'xgb__max_depth': 5, 'xgb__n_estimators': 44, 'xgb__subsample': 0.6701185734892561, 'xgb__colsample_bynode': 0.9316811090115041, 'xgb__reg_lambda': 9.718721552254326, 'lgbm__max_depth': 12, 'lgbm__n_estimators': 172, 'lgbm__learning_rate': 0.42545372486850586, 'lgbm__subsample': 0.9723027036874026, 'lgbm__reg_lambda': 6.346687433468941}. Best is trial 6 with value: 0.6179168246395897.
# [I 2026-08-02 08:15:04,380] Trial 11 finished with value: 0.6151685861000808 and parameters: {'rf__n_estimators': 54, 'rf__max_depth': 5, 'rf__max_samples': 0.7393063691084775, 'xgb__learning_rate': 0.11910424483722903, 'xgb__max_depth': 15, 'xgb__n_estimators': 199, 'xgb__subsample': 0.5292251295181767, 'xgb__colsample_bynode': 0.9932383834933138, 'xgb__reg_lambda': 9.531340422044648, 'lgbm__max_depth': 5, 'lgbm__n_estimators': 146, 'lgbm__learning_rate': 0.012282881827039347, 'lgbm__subsample': 0.5089985405459636, 'lgbm__reg_lambda': 9.944015878959618}. Best is trial 6 with value: 0.6179168246395897.
# [I 2026-08-02 08:15:05,960] Trial 12 finished with value: 0.6152184682093254 and parameters: {'rf__n_estimators': 59, 'rf__max_depth': 5, 'rf__max_samples': 0.758989376637679, 'xgb__learning_rate': 0.019246856483336624, 'xgb__max_depth': 15, 'xgb__n_estimators': 194, 'xgb__subsample': 0.5259701163865391, 'xgb__colsample_bynode': 0.9982519369335338, 'xgb__reg_lambda': 2.3159666188745724, 'lgbm__max_depth': 14, 'lgbm__n_estimators': 32, 'lgbm__learning_rate': 0.14819138714507574, 'lgbm__subsample': 0.890193537990292, 'lgbm__reg_lambda': 9.838373806758245}. Best is trial 6 with value: 0.6179168246395897.
# [I 2026-08-02 08:15:18,929] Trial 13 finished with value: 0.618677586202281 and parameters: {'rf__n_estimators': 54, 'rf__max_depth': 7, 'rf__max_samples': 0.7303730560158668, 'xgb__learning_rate': 0.1022496141918404, 'xgb__max_depth': 15, 'xgb__n_estimators': 199, 'xgb__subsample': 0.5049385480636506, 'xgb__colsample_bynode': 0.9770018436899651, 'xgb__reg_lambda': 9.429533380268921, 'lgbm__max_depth': 5, 'lgbm__n_estimators': 144, 'lgbm__learning_rate': 0.022364123405171674, 'lgbm__subsample': 0.5058756594804202, 'lgbm__reg_lambda': 9.971536513522533}. Best is trial 13 with value: 0.618677586202281.
# [I 2026-08-02 08:15:20,105] Trial 14 finished with value: 0.6167557860073638 and parameters: {'rf__n_estimators': 54, 'rf__max_depth': 7, 'rf__max_samples': 0.6877762350786871, 'xgb__learning_rate': 0.08264305000595056, 'xgb__max_depth': 12, 'xgb__n_estimators': 161, 'xgb__subsample': 0.51575190808151, 'xgb__colsample_bynode': 0.9963785738764616, 'xgb__reg_lambda': 2.3711487540614686, 'lgbm__max_depth': 13, 'lgbm__n_estimators': 36, 'lgbm__learning_rate': 0.1869991990673382, 'lgbm__subsample': 0.8831971499805422, 'lgbm__reg_lambda': 9.947410931060128}. Best is trial 13 with value: 0.618677586202281.
# [I 2026-08-02 08:15:34,553] Trial 15 finished with value: 0.6069715230214847 and parameters: {'rf__n_estimators': 91, 'rf__max_depth': 7, 'rf__max_samples': 0.6833975539156878, 'xgb__learning_rate': 0.10785702077726084, 'xgb__max_depth': 12, 'xgb__n_estimators': 161, 'xgb__subsample': 0.5564178366213619, 'xgb__colsample_bynode': 0.8209008526088609, 'xgb__reg_lambda': 0.17112722270194913, 'lgbm__max_depth': 5, 'lgbm__n_estimators': 137, 'lgbm__learning_rate': 0.010282437566364194, 'lgbm__subsample': 0.6805066604852688, 'lgbm__reg_lambda': 8.312894907327697}. Best is trial 13 with value: 0.618677586202281.
# [I 2026-08-02 08:15:35,229] Trial 16 finished with value: 0.6178992792272272 and parameters: {'rf__n_estimators': 86, 'rf__max_depth': 7, 'rf__max_samples': 0.5129443496000146, 'xgb__learning_rate': 0.20220235275389192, 'xgb__max_depth': 13, 'xgb__n_estimators': 155, 'xgb__subsample': 0.6038912178933995, 'xgb__colsample_bynode': 0.8113702349828039, 'xgb__reg_lambda': 8.19401357820611, 'lgbm__max_depth': 5, 'lgbm__n_estimators': 135, 'lgbm__learning_rate': 0.031015477064149394, 'lgbm__subsample': 0.6702527697389353, 'lgbm__reg_lambda': 8.523909720918638}. Best is trial 13 with value: 0.618677586202281.
# [I 2026-08-02 08:15:54,694] Trial 17 finished with value: 0.6098160421634714 and parameters: {'rf__n_estimators': 199, 'rf__max_depth': 7, 'rf__max_samples': 0.5252983457246286, 'xgb__learning_rate': 0.22700091376470607, 'xgb__max_depth': 13, 'xgb__n_estimators': 133, 'xgb__subsample': 0.6099562016380797, 'xgb__colsample_bynode': 0.7744139524170808, 'xgb__reg_lambda': 8.017645640002401, 'lgbm__max_depth': 10, 'lgbm__n_estimators': 131, 'lgbm__learning_rate': 0.10992502181292794, 'lgbm__subsample': 0.500975303454381, 'lgbm__reg_lambda': 8.348989737226708}. Best is trial 13 with value: 0.618677586202281.
# [I 2026-08-02 08:15:54,730] Trial 18 finished with value: 0.6128166812641147 and parameters: {'rf__n_estimators': 198, 'rf__max_depth': 6, 'rf__max_samples': 0.8377873073655789, 'xgb__learning_rate': 0.26845571475808616, 'xgb__max_depth': 14, 'xgb__n_estimators': 127, 'xgb__subsample': 0.7570303441557571, 'xgb__colsample_bynode': 0.765399969021683, 'xgb__reg_lambda': 7.999120292017922, 'lgbm__max_depth': 10, 'lgbm__n_estimators': 81, 'lgbm__learning_rate': 0.08796848034732502, 'lgbm__subsample': 0.5116811797393254, 'lgbm__reg_lambda': 8.42938409698164}. Best is trial 13 with value: 0.618677586202281.
# [I 2026-08-02 08:16:03,602] Trial 19 finished with value: 0.6115013014502402 and parameters: {'rf__n_estimators': 111, 'rf__max_depth': 6, 'rf__max_samples': 0.8248550848126254, 'xgb__learning_rate': 0.08182602019992524, 'xgb__max_depth': 15, 'xgb__n_estimators': 177, 'xgb__subsample': 0.7664834446618073, 'xgb__colsample_bynode': 0.9513831503203606, 'xgb__reg_lambda': 3.4366616466239766, 'lgbm__max_depth': 10, 'lgbm__n_estimators': 85, 'lgbm__learning_rate': 0.08709505844142904, 'lgbm__subsample': 0.5815448594317605, 'lgbm__reg_lambda': 6.930866900077335}. Best is trial 13 with value: 0.618677586202281.

# %%
# best parameters

study.best_params
# Out:
# {'rf__n_estimators': 54,
#  'rf__max_depth': 7,
#  'rf__max_samples': 0.7303730560158668,
#  'xgb__learning_rate': 0.1022496141918404,
#  'xgb__max_depth': 15,
#  'xgb__n_estimators': 199,
#  'xgb__subsample': 0.5049385480636506,
#  'xgb__colsample_bynode': 0.9770018436899651,
#  'xgb__reg_lambda': 9.429533380268921,
#  'lgbm__max_depth': 5,
#  'lgbm__n_estimators': 144,
#  'lgbm__learning_rate': 0.022364123405171674,
#  'lgbm__subsample': 0.5058756594804202,
#  'lgbm__reg_lambda': 9.971536513522533}

# %%
best_params = study.best_params

# %%
# best score
study.best_value
# Out:
# 0.618677586202281

# %%
# define models
rf = RandomForestClassifier(class_weight="balanced", random_state=42)
xgb = XGBClassifier(class_weight="balanced", random_state=42)
lgbm = LGBMClassifier(class_weight="balanced", random_state=42)

# build a voting classifier
model = VotingClassifier(estimators=[
    ("rf",rf),
    ("xgb",xgb),
    ("lgbm",lgbm)
], voting="soft",n_jobs=-1)

# pass the best params to model
model.set_params(**best_params)

model
# Out:
# VotingClassifier(estimators=[('rf',
#                               RandomForestClassifier(class_weight='balanced',
#                                                      max_depth=7,
#                                                      max_samples=0.7303730560158668,
#                                                      n_estimators=54,
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             class_weight='balanced',
#                                             colsample_bylevel=None,
#                                             colsample_bynode=0.9770018436899651,
#                                             colsample_bytree=None, device=None,
#                                             early_sto...
#                                             max_delta_step=None, max_depth=15,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=199, n_jobs=None, ...)),
#                              ('lgbm',
#                               LGBMClassifier(class_weight='balanced',
#                                              learning_rate=0.022364123405171674,
#                                              max_depth=5, n_estimators=144,
#                                              random_state=42,
#                                              reg_lambda=9.971536513522533,
#                                              subsample=0.5058756594804202))],
#                  n_jobs=-1, voting='soft')

# %%
# train the model

model.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('rf',
#                               RandomForestClassifier(class_weight='balanced',
#                                                      max_depth=7,
#                                                      max_samples=0.7303730560158668,
#                                                      n_estimators=54,
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             class_weight='balanced',
#                                             colsample_bylevel=None,
#                                             colsample_bynode=0.9770018436899651,
#                                             colsample_bytree=None, device=None,
#                                             early_sto...
#                                             max_delta_step=None, max_depth=15,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=199, n_jobs=None, ...)),
#                              ('lgbm',
#                               LGBMClassifier(class_weight='balanced',
#                                              learning_rate=0.022364123405171674,
#                                              max_depth=5, n_estimators=144,
#                                              random_state=42,
#                                              reg_lambda=9.971536513522533,
#                                              subsample=0.5058756594804202))],
#                  n_jobs=-1, voting='soft')

# %%
# get the predictions
y_pred = model.predict(X_test)

# %%
model.predict_proba(X_test.iloc[0:3, :])
# Out:
# array([[0.81881141, 0.1811886 ],
#        [0.84368134, 0.15631866],
#        [0.63158858, 0.36841143]])

# %%
# classification report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      1593
#            1       0.64      0.65      0.65       407
#
#     accuracy                           0.85      2000
#    macro avg       0.78      0.78      0.78      2000
# weighted avg       0.86      0.85      0.85      2000

# %% [markdown]
# ## SHAP

# %%
# make the explainer

explainer = shap.TreeExplainer(model=model,
                               data=X_train,
                               model_output="probability")
# Out:
# WARNING:shap:Background dataset has 8000 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=8000 when initializing the masker.
# ---------------------------------------------------------------------------
# InvalidModelError                         Traceback (most recent call last)
# /tmp/ipykernel_2304/1029071112.py in <cell line: 0>()
#       1 # make the explainer
#       2
# ----> 3 explainer = shap.TreeExplainer(model=model,
#       4                                data=X_train,
#       5                                model_output="probability")
#
# /usr/local/lib/python3.12/dist-packages/shap/explainers/_tree.py in __init__(self, model, data, model_output, feature_perturbation, feature_names, approximate, link, linearize_link)
#     287         self.feature_perturbation = feature_perturbation
#     288         self.expected_value = None
# --> 289         self.model = TreeEnsemble(model, self.data, self.data_missing, model_output)
#     290         self.model_output = model_output
#     291         # self.model_output = self.model.model_output # this allows the TreeEnsemble to translate model outputs types by how it loads the model
#
# /usr/local/lib/python3.12/dist-packages/shap/explainers/_tree.py in __init__(self, model, data, data_missing, model_output)
#    1529             self.base_offset = model.init_params[param_idx]
#    1530         else:
# -> 1531             raise InvalidModelError("Model type not yet supported by TreeExplainer: " + str(type(model)))
#    1532
#    1533         # build a dense numpy version of all the tree objects
#
# InvalidModelError: Model type not yet supported by TreeExplainer: <class 'sklearn.ensemble._voting.VotingClassifier'>

# %%
model
# Out:
# VotingClassifier(estimators=[('rf',
#                               RandomForestClassifier(class_weight='balanced',
#                                                      max_depth=7,
#                                                      max_samples=0.7303730560158668,
#                                                      n_estimators=54,
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             class_weight='balanced',
#                                             colsample_bylevel=None,
#                                             colsample_bynode=0.9770018436899651,
#                                             colsample_bytree=None, device=None,
#                                             early_sto...
#                                             max_delta_step=None, max_depth=15,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=199, n_jobs=None, ...)),
#                              ('lgbm',
#                               LGBMClassifier(class_weight='balanced',
#                                              learning_rate=0.022364123405171674,
#                                              max_depth=5, n_estimators=144,
#                                              random_state=42,
#                                              reg_lambda=9.971536513522533,
#                                              subsample=0.5058756594804202))],
#                  n_jobs=-1, voting='soft')

# %%
model.predict_proba(X_test.iloc[0:3])[:,1]
# Out:
# array([0.1811886 , 0.15631866, 0.36841143])

# %%
def prediction_fn(X):
    predictions = model.predict_proba(X)[:,1]
    return predictions

# %%
# model agnostic explainer

explainer = shap.Explainer(model=prediction_fn,
                           masker=X_train,
                           link=shap.links.identity)
# Out:
# WARNING:shap:Background dataset has 8000 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=8000 when initializing the masker.

# %%
X_train.shape[1]
# Out:
# 14

# %%
# calculate the shap values

shap_values = explainer(X_test.iloc[[1],:])

shap_values
# Out:
# .values =
# array([[ 0.00232881, -0.09492429,  0.020567  , -0.0106947 ,  0.0216924 ,
#          0.00788132, -0.00626996, -0.01553477,  0.00055079, -0.00111615,
#         -0.05658073, -0.0011016 , -0.02505123,  0.01028962]])
#
# .base_values =
# array([0.30428217])
#
# .data =
# array([[0.324     , 0.2027027 , 0.48499895, 0.41839191, 1.        ,
#         0.        , 1.        , 0.        , 0.        , 6.        ,
#         2.        , 1.        , 1.        , 0.        ]])

# %%
shap_values.shape
# Out:
# (1, 14)

# %%
model.predict_proba(X_test.iloc[[1],:])[:,1]
# Out:
# array([0.15631866])

# %%
shap.plots.waterfall(shap_values[0])

# %%
X_train.shape
# Out:
# (8000, 14)

# %%
X_test.shape
# Out:
# (2000, 14)

# %%
X_test.columns
# Out:
# Index(['creditscore', 'age', 'balance', 'estimatedsalary', 'gender_Female',
#        'gender_Male', 'geography_France', 'geography_Germany',
#        'geography_Spain', 'tenure', 'numofproducts', 'hascrcard',
#        'isactivemember', 'iszerobal'],
#       dtype='object')

# %%
# sample 500 rows from test data

test_data_sample = X_test.sample(500)

# %%
test_data_sample.shape
# Out:
# (500, 14)

# %%
# calculate shap values for the entire test data

shap_values = explainer(test_data_sample)
# Out:
# PermutationExplainer explainer: 501it [07:34,  1.08it/s]

# %%
shap_values.shape
# Out:
# (500, 14)

# %%
shap_values
# Out:
# .values =
# array([[ 0.00338086, -0.09261954, -0.00281662, ...,  0.00304674,
#         -0.01983364,  0.0079566 ],
#        [-0.01427948,  0.02979836, -0.04434221, ..., -0.00084492,
#         -0.09622202, -0.01722265],
#        [ 0.00292823, -0.12304616, -0.02230121, ..., -0.00025358,
#          0.03366839, -0.01534924],
#        ...,
#        [ 0.00172287, -0.03758599, -0.04694408, ...,  0.0001828 ,
#          0.04382648, -0.02180122],
#        [-0.01003275,  0.12231669, -0.03895276, ..., -0.00059036,
#         -0.04559667, -0.01710519],
#        [-0.00495464, -0.00913849,  0.03220243, ..., -0.0013004 ,
#          0.04765541,  0.01339641]])
#
# .base_values =
# array([0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217,
#        0.30428217, 0.30428217, 0.30428217, 0.30428217, 0.30428217])
#
# .data =
# array([[0.442     , 0.21621622, 0.39587802, ..., 0.        , 1.        ,
#         0.        ],
#        [0.654     , 0.72972973, 0.        , ..., 1.        , 1.        ,
#         1.        ],
#        [0.28      , 0.14864865, 0.        , ..., 1.        , 0.        ,
#         1.        ],
#        ...,
#        [0.676     , 0.28378378, 0.        , ..., 1.        , 0.        ,
#         1.        ],
#        [0.922     , 0.36486486, 0.        , ..., 1.        , 1.        ,
#         1.        ],
#        [0.668     , 0.31081081, 0.47741583, ..., 0.        , 0.        ,
#         0.        ]])

# %% [markdown]
# ### Global Plots

# %%
# bar plot

shap.plots.bar(shap_values)

# %%
# summary plot

shap.plots.beeswarm(shap_values)

# %%
# violin plot

shap.plots.violin(shap_values)

# %%
# heatmap plot

shap.plots.heatmap(shap_values)
# Out:
# <Axes: xlabel='Instances'>

# %% [markdown]
# ### Local Plots

# %%
test_case = X_test[y_test == 1].sample(1)

row_shap_values = explainer(test_case)[0]

# %%
row_shap_values.shape
# Out:
# (14,)

# %%
df.loc[test_case.index]
# Out:
#       creditscore geography gender  age  tenure  balance  numofproducts  \
# 1354          611     Spain   Male   52       7      0.0              1
#
#       hascrcard  isactivemember  estimatedsalary  exited
# 1354          0               1         73585.18       1

# %%
# waterfall plot

shap.plots.waterfall(row_shap_values, max_display=5)

# %%
# bar plot--> local

shap.plots.bar(row_shap_values, max_display=5)

# %%
# row force plot

shap.initjs()

shap.plots.force(row_shap_values)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={543(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",l="__lodash_placeholder__",u=32,s=128,c=1/0,f=9007199254740991,d=NaN,p=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",u],["partialRight",64],["rearg",256]],g="[object Arguments]",v="[object Array]",m="[object Boolean]",y="[object Date]",b="[object Error]",w="[object Function]",_="[object GeneratorFunction]",k="[object Map]",x="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",P="[object Set]",T="[object String]",O="[object Symbol]",z="[object WeakMap]",N="[object ArrayBuffer]",M="[object DataView]",A="[object Float32Array]",L="[object Float64Array]",j="[object Int8Array]",F="[object Int16Array]",D="[object Int32Array]",R="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,H=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,W=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(W.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,X=/<%=([\s\S]+?)%>/g,Z=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,le=/,? & /,ue=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,de=/\w*$/,pe=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ge=/^\[object .+?Constructor\]$/,ve=/^0o[0-7]+$/i,me=/^(?:0|[1-9]\d*)$/,ye=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,we=/['\n\r\u2028\u2029\\]/g,_e="\\ud800-\\udfff",ke="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",xe="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Pe="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Te="["+_e+"]",Oe="["+Pe+"]",ze="["+ke+"]",Ne="\\d+",Me="["+xe+"]",Ae="["+Se+"]",Le="[^"+_e+Pe+Ne+xe+Se+Ee+"]",je="\\ud83c[\\udffb-\\udfff]",Fe="[^"+_e+"]",De="(?:\\ud83c[\\udde6-\\uddff]){2}",Re="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Ae+"|"+Le+")",Be="(?:"+Ue+"|"+Le+")",He="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",We="(?:"+ze+"|"+je+")?",qe="["+Ce+"]?",Qe=qe+We+"(?:"+Ie+"(?:"+[Fe,De,Re].join("|")+")"+qe+We+")*",Ye="(?:"+[Me,De,Re].join("|")+")"+Qe,Ge="(?:"+[Fe+ze+"?",ze,De,Re,Te].join("|")+")",Ke=RegExp("['’]","g"),Xe=RegExp(ze,"g"),Ze=RegExp(je+"(?="+je+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Ae+"+"+He+"(?="+[Oe,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Oe,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+He,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",Ne,Ye].join("|"),"g"),et=RegExp("["+Ie+_e+ke+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[A]=at[L]=at[j]=at[F]=at[D]=at[R]=at[U]=at[I]=at[$]=!0,at[g]=at[v]=at[N]=at[m]=at[M]=at[y]=at[b]=at[w]=at[k]=at[x]=at[S]=at[C]=at[P]=at[T]=at[z]=!1;var it={};it[g]=it[v]=it[N]=it[M]=it[m]=it[y]=it[A]=it[L]=it[j]=it[F]=it[D]=it[k]=it[x]=it[S]=it[C]=it[P]=it[T]=it[O]=it[R]=it[U]=it[I]=it[$]=!0,it[b]=it[w]=it[z]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},lt=parseFloat,ut=parseInt,st="object"==typeof n ...
# <div id='i219KM81SNLKBGGJJDTK7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.3042821680088192, "outValue": 0.5401800046220069, "link": "identity", "featureNames": ["creditscore", "age", "balance", "estimatedsalary", "gender_Female", "gender_Male", "geography_France", "geography_Germany", "geography_Spain", "tenure", "numofproducts", "hascrcard", "isactivemember", "iszerobal"], "features": {"0": {"effect": 0.022428495623695865, "value": 0.5219999999999999}, "1": {"effect": 0.23506235189067393, "value": 0.4594594594594595}, "2": {"effect": 0.022631917983953406, "value": 0.0}, "3": {"effect": -0.004956514858753654, "value": 0.36790313474936853}, "4": {"effect": -0.02438783627030027, "value": 0.0}, "5": {"effect": -0.005699886661235678, "value": 1.0}, "6": {"effect": -0.0017523754797562172, "value": 0.0}, "7": {"effect": -0.008813553540298271, "value": 0.0}, "8": {"effect": -0.03144324579913696, "value": 1.0}, "9": {"effect": -0.013427344697130531, "value": 7.0}, "10": {"effect": 0.13504325056232797, "value": 1.0}, "11": {"effect": 0.009648697232667189, "value": 0.0}, "12": {"effect": -0.0958477504288916, "value": 1.0}, "13": {"effect": -0.0025883689446275894, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i219KM81SNLKBGGJJDTK7')
#   );
# </script>

# %%
row_shap_values
# Out:
# .values =
# array([ 0.0224285 ,  0.23506235,  0.02263192, -0.00495651, -0.02438784,
#        -0.00569989, -0.00175238, -0.00881355, -0.03144325, -0.01342734,
#         0.13504325,  0.0096487 , -0.09584775, -0.00258837])
#
# .base_values =
# np.float64(0.3042821680088192)
#
# .data =
# array([0.522     , 0.45945946, 0.        , 0.36790313, 0.        ,
#        1.        , 0.        , 0.        , 1.        , 7.        ,
#        1.        , 0.        , 1.        , 1.        ])

# %%
# decision plot

shap.plots.decision(shap_values=row_shap_values.values, base_value=row_shap_values.base_values,
                    feature_names=X_test.columns.tolist())

# %% [markdown]
# ### Batch Data Plots

# %%
# sample of test data
sample_batch_data = X_test.sample(3)

# shap_values
batch_shap_values = explainer(sample_batch_data)

# %%
batch_shap_values.shape
# Out:
# (3, 14)

# %%
# decision plot

shap.plots.decision(shap_values=batch_shap_values.values, base_value=batch_shap_values.base_values[0],
                    feature_names=X_test.columns.tolist())

# %% [markdown]
# ## LIME

# %%
# test case

test_case_lime = test_case.values.flatten()

# %%
! pip install lime
# Out:
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from lime) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from lime) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lime) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from lime) (4.67.3)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.12/dist-packages (from lime) (1.6.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.12/dist-packages (from lime) (0.25.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (2026.4.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (26.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.18->lime) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.18->lime) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=ad4e88588a321376f32cf194272e2edbf493f67d581eadcc55860f944f03d063
#   Stored in directory: /root/.cache/pip/wheels/e7/5d/0e/4b4fff9a47468fed5633211fb3b76d1db43fe806a17fb7486a
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1

# %%
from lime.lime_tabular import LimeTabularExplainer

# %%
feature_names = preprocessor.get_feature_names_out().tolist()

# %%
preprocessor.get_feature_names_out()
# Out:
# array(['creditscore', 'age', 'balance', 'estimatedsalary',
#        'gender_Female', 'gender_Male', 'geography_France',
#        'geography_Germany', 'geography_Spain', 'tenure', 'numofproducts',
#        'hascrcard', 'isactivemember', 'iszerobal'], dtype=object)

# %%
# list of index numbers of categorical features in data

categorical_features = [4, 5, 6, 7, 8, 11, 12, 13]

# %%
# create the explainer

lime_explainer = LimeTabularExplainer(
    training_data=X_train.values,
    mode="classification",
    feature_names=feature_names,
    categorical_features=categorical_features
)

# %%
# create an explanation

lime_explanation = lime_explainer.explain_instance(data_row=test_case_lime,
                                                   predict_fn=model.predict_proba)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
# view my explanations --> as a list

lime_explanation.as_list()
# Out:
# [('age > 0.35', 0.3082269595312896),
#  ('numofproducts <= 1.00', 0.1355287363289082),
#  ('isactivemember=1', -0.13073663345819125),
#  ('gender_Female=0', -0.042950091616352166),
#  ('iszerobal=1', -0.02397814334290549),
#  ('geography_Germany=0', -0.02303887832845318),
#  ('balance <= 0.00', -0.02171505625897572),
#  ('geography_Spain=1', -0.013848379495344641),
#  ('gender_Male=1', -0.009791840490110478),
#  ('geography_France=0', 0.007697384412918935)]

# %%
from IPython.core.display import HTML

# %%
display(HTML(lime_explanation.as_html()))
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s
